# %%
import pandas as pd
import numpy as np
import math
import missingno as mn
import matplotlib.pyplot as plt

# %%
initial_data = pd.read_csv('C:\\Users\\George\\Downloads\\MITM\\open_pubs.csv', sep = ',#,', error_bad_lines = False, header = None)
# Out:
# C:\Users\George\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   """Entry point for launching an IPython kernel.

# %%
#filter it to only london pubs
#initial_data.head(10)

listlondon = []
listlondon = ('Camden'
,'Royal Borough of Greenwich'
,'Hackney'
, 'City of London'
,'Hammersmith and Fulham'
,'Islington'
,'Royal Borough of Kensington and Chelsea'
,'Lambeth'
,'Lewisham'
,'Southwark'
,'Tower Hamlets'
,'Wandsworth'
,'City of Westminster'
,'Barking and Dagenham'
,'Barnet'
,'Bexley'
,'Brent'
,'Bromley'
,'Croydon'
,'Ealing'
,'Enfield'
,'Haringey'
,'Harrow'
,'Havering'
,'Hillingdon'
,'Hounslow'
,'Royal Borough of Kingston upon Thames'
,'Merton'
,'Newham'
,'Redbridge'
,'Richmond upon Thames'
,'Sutton'
,'Waltham Forest'
)

# %%
london_pubs = pd.DataFrame(initial_data[initial_data[8].isin(listlondon)])

# %%
#london_pubs.head(10)
london_pubs[london_pubs[8] == 'City of London']
# Out:
#             0                               1  \
# 9775    96925                        37 Jewry
# 9776    96926                           Abbey
# 9777    96945                     All Bar One
# 9778    96946                     All Bar One
# 9779    96947                     All Bar One
# 9780    96948                     All Bar One
# 9781    96949                     All Bar One
# 9782    96952                       Amber Bar
# 9783    96982                      Astronomer
# 9784    96988                     Babble City
# 9785    96997  Balls Brothers @ Minster Court
# 9786    96998    Balls Brothers Austin Friars
# 9787    96999        Balls Brothers Shoe Lane
# 9788    97000         Balls Brothers Wine Bar
# 9789    97002     "Balls Brothers, Mark Lane"
# 9790    97004                         Bangers
# 9791    97009                          Bar 20
# 9792    97013                   Barbican Bars
# 9793    97040              Bavarian Beerhouse
# ...

# %%
#now need to query google with the distance in time between two user inputs and the list of pubs
import googlemaps as gm
from datetime import datetime

#gmaps = googlemaps.Client(key='Add Your Key here')

# Geocoding an address
#geocode_result = gmaps.geocode('1600 Amphitheatre Parkway, Mountain View, CA')

# Look up an address with reverse geocoding
#reverse_geocode_result = gmaps.reverse_geocode((40.714224, -73.961452))

# Request directions via public transit
#now = datetime.now()
#directions_result = gmaps.directions("Sydney Town Hall",
#                                     "Parramatta, NSW",
#                                     mode="transit",
#                                     departure_time=now)

user_locs = ['E149EG','W1U6BZ']

# %%
gmaps = gm.Client(key='AIzaSyCg62MwCKnfFpIH6Ynqnn9UlHcl6kFqA34')
now = datetime.now()

# %%
#    directions_result = gmaps.directions(user_loc,
#                                     'w42qx',
#                                     mode="transit",
#                                     departure_time=now)

# %%
#for postcode in london_pubs[3]:
#    directions_result = gmaps.directions(user_loc,
#                                     postcode,
#                                     mode="transit",
#                                     departure_time=now)
user_locs
filter_boroughs = ('Camden', 'Islington','City of Westminster','Hackney','Southwark'
,'Tower Hamlets','Hackney')

# %%
testing_set = london_pubs[london_pubs[8].isin(filter_boroughs)]
testing_set = testing_set.reset_index()

# %%
testing_set
# Out:
#      index       0                           1  \
# 0     9516   94087                Abbey Tavern
# 1     9517   94096  Aces and Eights Saloon Bar
# 2     9518   94098            Acol Bridge Club
# 3     9519   94127         Alexander the Great
# 4     9520   94129                 Alice House
# 5     9521   94132                 All Bar One
# 6     9522   94133                 All Bar One
# 7     9523   94199            Astor Museum Inn
# 8     9524   94244           Be At One Limited
# 9     9525   94265                   Belushi's
# 10    9526   94284               Betjeman Arms
# 11    9527   94304                 Black Heart
# 12    9528   94327           Bloomsbury Tavern
# 13    9529   94365      Bourne & Hollingsworth
# 14    9530   94387            Bricklayers Arms
# 15    9531   94402                 Bull & Bush
# 16    9532   94403                 Bull & Last
# 17    9533   94404               Bull and Gate
# 18    9534   94492                  Callaghans
# ...

# %%
testing_set[3] = testing_set[3].astype(str)
count =1
for value in user_locs:
    user_loc = value
    label = count
    pub_names = []
    time_in_secs = []
    time_in_time = []
    distance_in_distance = []
    now = datetime.now()

    for postcode in testing_set[3]:

        current_postcode = postcode
        
        distance_result = gmaps.distance_matrix(user_loc, postcode,mode="transit",departure_time=now)

        try:
            distance_result = distance_result['rows'][0]
            distance_result = distance_result['elements'][0]
            time_in_secs.append(distance_result['duration']['value'])
            time_in_time.append(distance_result['duration']['text'])
            distance_in_distance.append(distance_result['distance']['text'])
        except:
            print(postcode)
    time_in_secs = pd.DataFrame(time_in_secs)
    time_in_secs.columns = ['seconds ' + str(count)]

    time_in_time= pd.DataFrame(time_in_time)
    time_in_time.columns = ['time ' + str(count)]

    distance_in_distance = pd.DataFrame(distance_in_distance)
    distance_in_distance.columns = ['distance ' + str(count)]

    temp = pd.merge(time_in_secs,time_in_time,left_index = True, right_index = True)
    temp2 = pd.merge(temp,distance_in_distance, left_index = True,right_index = True)
    testing_set = pd.merge(testing_set,temp2, left_index = True, right_index = True)
    
    count += 1
# Out:
# N1 9DT
# N1 9DT

# %%
distance_result
# Out:
# {'distance': {'text': '7.5 km', 'value': 7535},
#  'duration': {'text': '27 mins', 'value': 1590},
#  'status': 'OK'}

# %%
#distance_result = distance_result['rows'][0]
#distance_result = distance_result['elements'][0]
#time_in_secs
testing_set['combined_time'] = testing_set['seconds 1'] + testing_set['seconds 2']

# %%
top5 = testing_set.sort_values(by = 'combined_time').head(5)

# %%
top5
# Out:
#      index       0                      1  \
# 641  12399  137007  Doggetts coat & badge
# 880  12678  141936       Sir Sidney Smith
# 795  12553  138908        Thomas a becket
# 736  12494  138773          The gladstone
# 902  12700  142225        The Ferry House
#
#                                                      2         3       4  \
# 641  "Doggetts Coat And Badge Black, Blackfriars Ro...   SE1 9UD  531617
# 880                           "22 Dock Street, London"    E1 8JP  534129
# 795  "Thomas A Becket, 320-322, Old Kent Road, London"   SE1 5UE  533570
# 736             "24-26, King And Queen Street, London"  SE17 1DQ  532488
# 902  "Ferry House Public House, 26 Ferry Street, Lo...   E14 3DT  538104
#
#             5          6          7              8  seconds 1   time 1  \
# 641  180539.0  51.508461  -0.104866      Southwark       1383  23 mins
# 880  180824.0  51.510432  -0.068584  Tower Hamlets        267   4 mins
# ...

# %%
#time_in_secs = distance_result['duration']['value']
#time_in_time = distance_result['duration']['text']
#distance_in_distance = distance_result['duration']['text']
#distance_result
#testing_set

# %%
top20 = testing_set.sort_values(by = 'combined_time').head(20)

# %%
top20
# Out:
#       index       0                                   1  \
# 1499  10798  111976                The Stonemasons Arms
# 2921  12444  138221                      Queen victoria
# 1393  10692  110477                           Belushi's
# 1504  10803  111986                     The White Horse
# 1472  10771  111928                 The Havelock Tavern
# 3075  12598  139981                        93 Feet East
# 1390  10689  110383                        Aragon House
# 2847  12370  136322                      56 social club
# 2861  12384  136517  Belushis & st christophers village
# 2305  11827  127444                             Taylors
# 1457  10756  111895                        The Crabtree
# 2872  12395  136855                            Club 701
# 2856  12379  136469                      Balls brothers
# 2992  12515  138811                The leather exchange
# 3018  12541  138879                         The tankard
# 3001  12524  138829                      The montpelier
# ...

# %%
top5_combined = testing_set.sort_values(by = 'combined_time').head(5)
testing_set['difference'] = abs(testing_set['seconds 1'] - testing_set['seconds 2'])

# %%
top20_evens = testing_set.sort_values(by = 'difference').head(20)

# %%
#top20_evens.sort_values(by = 'combined time')
top20_evens = testing_set.sort_values(by = 'difference')
top20_evens = top20_evens.head(20)

# %%
top20_evens = top20_evens.sort_values(by= 'combined_time')

# %%
top20_evens
# Out:
#      index       0                                    1  \
# 784  12542  138882                            The tiger
# 797  12555  139043                  Whelan's free house
# 761  12519  138820                         The lordship
# 809  12607  140073                        Artful Dodger
# 543  11438  121877                       The Angelic PH
# 587  11482  122002  The Shakespeare's Head Public House
# 872  12670  141718                          Queens Head
# 581  11476  121979         The Narrow Boat Public House
# 501  11396  121086                         Island Queen
# 820  12618  140392                         Captain Kidd
# 585  11480  121995                           The Regent
# 349  10575  109483                           Prague Bar
# 357  10583  109571                        Rolling Stock
# 270  10496  107982                         Basing House
# 298  10524  108426                   Duke Of Wellington
# 613  11508  122139                    York Public House
# ...

# %%
stored_firstrun = testing_set

# %%
stored_firstrun
# Out:
#       index       0                                     1  \
# 0      1875   17820              The Three Jolly Wheelers
# 1      8950   85383                              Aria Bar
# 2      8951   85412                      Barking Arms Ltd
# 3      8952   85420                 Barking football Club
# 4      8953   85423         Barking Indoor Bowls Club Ltd
# 5      8954   85429     Barking Rugby Union Football Club
# 6      8955   85436          Barking United Services Club
# 7      8956   85440                           Beacon Tree
# 8      8957   85519           Chadwell Heath Cricket Club
# 9      8958   85589                      Dagenham Bowling
# 10     8959   85590   Dagenham Conservative & Social Club
# 11     8960   85599                  Dagenham Trades Hall
# 12     8961   85611                          Deuce Lounge
# 13     8962   85628                       Eastbrook Hotel
# 14     8963   85828                          Kings Lounge
# ...

# %%
#attempt to loop through the pubs and pull all google data about them
#distance_result = gmaps.distance_matrix(user_loc, 
#                                        postcode,mode="transit",
#                                        departure_time=now)

from googleplaces import GooglePlaces, types, lang
google_places = GooglePlaces('AIzaSyCg62MwCKnfFpIH6Ynqnn9UlHcl6kFqA34')

# %%
query_result = google_places.nearby_search(
        location='London, England',
        radius=20000, types=[types.TYPE_BAR])
#actual_query = google_find_place()
# Out:
# ---------------------------------------------------------------------------
# GooglePlacesError                         Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\googleplaces\__init__.py in _generate_lat_lng_string(self, lat_lng, location)
#     589             return '%(lat)s,%(lng)s' % (lat_lng if lat_lng is not None
# --> 590                     else geocode_location(location=location, api_key=self.api_key))
#     591         except GooglePlacesError as e:
#
# ~\Anaconda3\lib\site-packages\googleplaces\__init__.py in geocode_location(location, sensor, api_key)
#     118             GooglePlaces.GEOCODE_API_URL, params)
# --> 119     _validate_response(url, geo_response)
#     120     if geo_response['status'] == GooglePlaces.RESPONSE_STATUS_ZERO_RESULTS:
#
# ~\Anaconda3\lib\site-packages\googleplaces\__init__.py in _validate_response(url, response)
#     174                         (url, response['status']))
# ...

# %%
query_result
# Out:
# <GooglePlacesSearchResult with 20 result(s)>

# %%
print(query_result)
# Out:
# <GooglePlacesSearchResult with 20 result(s)>

# %%
##### function to search google places ratings #####
def GetGooglePlacesRatings(restaurants):
    # 'restaurants': array of dicts = [{u"name":u"El Celler de Can Roca",u"location":u"Girona"},{u"name":u"Koy Shunka",u"location":u"Barcelona"}]
 
    # set google places api
    from googleplaces import GooglePlaces, types, lang
    google_places_api_key = 'AIzaSyCg62MwCKnfFpIH6Ynqnn9UlHcl6kFqA34'
    google_places = GooglePlaces(google_places_api_key)
     
    # search restaurants
    for restaurant in restaurants:
        restaurantFound = 0
        restaurantName = restaurant["name"].lower()
        restaurantLocation = restaurant["location"].lower()
 
        query_result = google_places.nearby_search(keyword=restaurantName, location=restaurantLocation, radius="50000", types=[types.TYPE_FOOD], sensor="false")
         
        # loop query results
        for place in query_result.places:
            if (restaurantName == place.name.lower() or
                'restaurant ' + restaurantName  == place.name.lower() or
                'restaurante ' + restaurantName == place.name.lower() or
                restaurantName + ' restaurant'  == place.name.lower() or
                restaurantName + ' restaurante'  == place.name.lower() or
                'restaurant ' + place.name.lower()  == restaurantName or
                'restaurante ' + place.name.lower() == restaurantName or
                place.name.lower() + ' restaurant'  == restaurantName or
                place.name.lower() + ' restaurante'  == restaurantName
                ):
                place.get_details()
                if 'user_ratings_total' in place.details:
                    restarurantNumRatings=place.details['user_ratings_total']
                else:
                    restarurantNumRatings='-'
                print(place.name, '\t', place.rating, '\t', restarurantNumRatings)
                restaurantFound = 1
                break
         
        # restaurant not found, print query results for further manual inspection
        if(restaurantFound==0):
            print(restaurant["name"]), '\t-\t-\t(',
            for place in query_result.places:
                print(place.name + ' - '),
            print(')')
    return

# %%
GetGooglePlacesRatings(['wagamama'])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-257-9fcbc26600a2> in <module>()
# ----> 1 GetGooglePlacesRatings(['wagamama'])
#
# <ipython-input-255-874eb36b0bc8> in GetGooglePlacesRatings(restaurants)
#      11     for restaurant in restaurants:
#      12         restaurantFound = 0
# ---> 13         restaurantName = restaurant["name"].lower()
#      14         restaurantLocation = restaurant["location"].lower()
#      15
#
# TypeError: string indices must be integers

# %%
#from api_keys import GOOGLE_API_KEY
import json

from contextlib import closing
from urllib2 import urlopen


class Business:
    def __init__(self, name, address, rating, rating_count, checkin_count):
        self.name = name
        self.address = address
        self.rating = rating
        self.rating_count = rating_count
        self.checkin_count = checkin_count
        self.bayesian = 0.0
        self.source_count = 1


def make_request(url):
    """
    Makes a new HTTP request to the given URL
    :param url: The URL to request
    :returns: JSON response
    """

    with closing(urlopen(url)) as response:
        return json.loads(response.read())
from business import Business, make_request

google_places_api_key = 'AIzaSyCg62MwCKnfFpIH6Ynqnn9UlHcl6kFqA34'

SEARCH_URL = 'https://maps.googleapis.com/maps/api/place/nearbysearch/json?location={},{}&radius={}&types=bar&key={}'
PLACE_URL = 'https://maps.googleapis.com/maps/api/place/details/json?placeid={}&key={}'


def search(lat, lng, distance):
    """
    Searches the Google Places API (Max Limit = 20)
    :param lat: Latitude of the request
    :param long: Longitude of the request
    :param distance: Distance to search (meters)
    :returns: List of retrieved places
    """

    url = SEARCH_URL.format(lat, lng, distance, google_places_api_key)
    place_list = []

    try:
        data = make_request(url)

        for result in data['results']:
            place = search_place(result['place_id'])
            place_list.append(place)

    except:
        print(e)

    return place_list


def search_place(place_id):

    """
    Searches Google for a specific Place
    :param id: Google Place ID
    :returns: Business object
    """

    url = PLACE_URL.format(place_id, GOOGLE_API_KEY)

    try:
        data = make_request(url)

        place = data['result']
        return Business(place['name'],
                        place['formatted_address'].split(',')[0],
                        place['rating'],
                        place['user_ratings_total'],
                        'N/A')
    except:
        print(e)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-271-1dc48c9c667e> in <module>()
#       3
#       4 from contextlib import closing
# ----> 5 from urllib2 import urlopen
#       6
#       7
#
# ModuleNotFoundError: No module named 'urllib2'
